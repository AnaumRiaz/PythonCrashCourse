# %%
import json

filename = 'data/eq_data_1_day_m1.json'
filename1 = 'data/eq_data_30_day_m1.json'

with open(filename) as f:
    all_eq_data = json.load(f)
    
readable_file = 'data/readable_eq_data.json'

with open(readable_file, 'w') as f:
    json.dump(all_eq_data, f, indent=4)
    
all_eq_dicts = all_eq_data['features']

# %%
import json

filename = 'data/eq_data_1_day_m1.json'
filename1 = 'data/eq_data_30_day_m1.json'

with open(filename1) as f:
    all_eq_data = json.load(f)
    
readable_file = 'data/readable_eq30_data.json'

with open(readable_file, 'w') as f:
    json.dump(all_eq_data, f, indent=4)
    
all_eq_dicts = all_eq_data['features']


from plotly.graph_objs import Scattergeo, Layout
from plotly import offline

mags, lons, lats, hover_texts = [], [], [], []

for eq_dict in all_eq_dicts:
    title = eq_dict['properties']['title']
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)
    hover_texts.append(title)
    
data = [{
    'type': 'scattergeo',
    'lon' : lons, 
    'lat' : lats,
    'text': hover_texts,
    'marker': {'size': [5*mag for mag in mags],
              'color': mags,
              'colorscale': 'Reds', #'Viridis',
              'reversescale': False,  #reverse the scale
              'colorbar': {'title': 'Magnitude'}
              }
}]

my_layout = Layout(title='Global Earthquakes')
fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='global_earthquakes.html')
# Out:
# 'global_earthquakes.html'

# %%
from plotly import colors
for key in colors.PLOTLY_SCALES.keys():
    print(key)
# Out:
# Greys
# YlGnBu
# Greens
# YlOrRd
# Bluered
# RdBu
# Reds
# Blues
# Picnic
# Rainbow
# Portland
# Jet
# Hot
# Blackbody
# Earth
# Electric
# Viridis
# Cividis

# %%
import json

filename1 = 'data/eq_data_7_day_m1.json'

with open(filename1) as f:
    all_eq_data = json.load(f)
    
# readable_file = 'data/readable_eq30_data.json'
title_graph = all_eq_data['metadata']['title']
# with open(readable_file, 'w') as f:
#     json.dump(all_eq_data, f, indent=4)  #basically indent = 4 makes it readable
    
all_eq_dicts = all_eq_data['features']


from plotly.graph_objs import Scattergeo, Layout
from plotly import offline

mags, lons, lats, hover_texts = [], [], [], []

for eq_dict in all_eq_dicts:    
    mags.append(eq_dict['properties']['mag'])
    lons.append(eq_dict['geometry']['coordinates'][0])
    lats.append(eq_dict['geometry']['coordinates'][1])
    hover_texts.append(eq_dict['properties']['title'])
    
data = [{
    'type': 'scattergeo',
    'lon' : lons, 
    'lat' : lats,
    'text': hover_texts,
    'marker': {'size': [5*mag for mag in mags],
              'color': mags,
              'colorscale': 'Reds', #'Viridis',
              'reversescale': False,  #reverse the scale
              'colorbar': {'title': 'Magnitude'}
              }
}]


my_layout = Layout(title=title_graph)
fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='global_earthquakes.html')
# Out:
# 'global_earthquakes.html'

# %%
#recent earthquakes

import json

filename1 = 'data/4.5_month.geojson.json'

with open(filename1) as f:
    all_eq_data = json.load(f)

title_graph = all_eq_data['metadata']['title']    
all_eq_dicts = all_eq_data['features']


from plotly.graph_objs import Scattergeo, Layout
from plotly import offline

mags, lons, lats, hover_texts = [], [], [], []

for eq_dict in all_eq_dicts:    
    mags.append(eq_dict['properties']['mag'])
    lons.append(eq_dict['geometry']['coordinates'][0])
    lats.append(eq_dict['geometry']['coordinates'][1])
    hover_texts.append(eq_dict['properties']['title'])
    
    
data = [{
    'type': 'scattergeo',
    'lon' : lons, 
    'lat' : lats,
    'text': hover_texts,
    'marker': {'size': [5*mag for mag in mags],
              'color': mags,
              'colorscale': 'Reds', #'Viridis',
              'reversescale': False,  #reverse the scale
              'colorbar': {'title': 'Magnitude'}
              }
}]

print('sizemarker: ', [5*mag for mag in mags])
print('color is ', mags)
my_layout = Layout(title=title_graph)
fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='global_earthquakes.html')
# Out:
# sizemarker:  [23.0, 23.5, 22.5, 23.0, 24.0, 25.5, 26.0, 25, 22.5, 24.5, 26.0, 24.0, 26.0, 23.5, 24.0, 25, 25, 24.0, 25, 24.5, 23.5, 23.5, 22.5, 29.5, 23.5, 23.0, 22.5, 23.0, 23.0, 22.5, 24.5, 25, 22.5, 25, 26.5, 24.0, 27.0, 24.5, 24.0, 24.35, 25.5, 24.0, 25, 23.5, 22.5, 23.5, 22.5, 23.0, 23.5, 24.0, 23.5, 23.5, 23.5, 26.0, 26.0, 23.0, 25.5, 26.0, 23.5, 22.5, 23.5, 25.5, 24.0, 27.5, 24.0, 23.0, 26.5, 24.5, 22.5, 27.0, 26.0, 24.5, 26.0, 23.0, 32.5, 24.0, 22.5, 23.0, 24.5, 22.5, 24.0, 23.0, 22.5, 22.5, 24.5, 23.5, 27.5, 23.0, 23.5, 26.5, 24.0, 24.5, 22.5, 23.0, 22.5, 26.0, 24.0, 24.5, 23.5, 23.0, 28.0, 25.5, 25.5, 22.5, 22.5, 24.5, 23.5, 23.0, 26.0, 26.5, 22.5, 29.0, 24.0, 29.0, 23.5, 22.5, 24.5, 25, 22.5, 22.5, 24.5, 22.5, 22.5, 22.5, 22.5, 23.0, 26.0, 28.0, 22.5, 26.5, 22.5, 22.5, 23.0, 23.5, 28.5, 22.5, 24.0, 27.0, 23.0, 30.5, 25, 23.0, 23.5, 24.0, 25, 24.0, 25.5, 27.0, 23.0, 23.0, 23.0, 23.0, 22.5, 25, 25.5, 22.5, 24.0, 23.5, 22.5, 25.5, 23.0, 24.0, 37.5, 23.5, 23.5, 24.5, 24.0, 24.
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-1b6f817dea50> in <module>
# ----> 1 marker.cmax
#
# NameError: name 'marker' is not defined

# %%
mags
# Out:
# [4.6,
#  4.7,
#  4.5,
#  4.6,
#  4.8,
#  5.1,
#  5.2,
#  5,
#  4.5,
#  4.9,
#  5.2,
#  4.8,
#  5.2,
#  4.7,
#  4.8,
#  5,
#  5,
#  4.8,
#  5,
#  4.9,
#  4.7,
#  4.7,
#  4.5,
#  5.9,
#  4.7,
#  4.6,
#  4.5,
#  4.6,
#  4.6,
#  4.5,
#  4.9,
#  5,
#  4.5,
#  5,
#  5.3,
#  4.8,
#  5.4,
#  4.9,
#  4.8,
#  4.87,
#  5.1,
#  4.8,
#  5,
#  4.7,
#  4.5,
#  4.7,
#  4.5,
#  4.6,
#  4.7,
#  4.8,
#  4.7,
#  4.7,
#  4.7,
#  5.2,
#  5.2,
#  4.6,
#  5.1,
#  5.2,
#  4.7,
#  4.5,
#  4.7,
#  5.1,
#  4.8,
#  5.5,
#  4.8,
#  4.6,
#  5.3,
#  4.9,
#  4.5,
#  5.4,
#  5.2,
#  4.9,
#  5.2,
#  4.6,
#  6.5,
#  4.8,
#  4.5,
#  4.6,
#  4.9,
#  4.5,
#  4.8,
#  4.6,
#  4.5,
#  4.5,
#  4.9,
#  4.7,
#  5.5,
#  4.6,
#  4.7,
#  5.3,
#  4.8,
#  4.9,
#  4.5,
#  4.6,
#  4.5,
#  5.2,
#  4.8,
#  4.9,
#  4.7,
#  4.6,
#  5.6,
#  5.1,
#  5.1,
#  4.5,
#  4.5,
#  4.9,
#  4.7,
#  4.6,
#  5.2,
#  5.3,
#  4.5,
#  5.8,
#  4.8,
#  5.8,
#  4.7,
#  4.5,
#  4.9,
#  5,
#  4.5,
#  4.5,
#  4.9,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.6,
# ...
